# %% [markdown]
# # <center>Analysing Customer Credit Card Information</center>

# %% [markdown]
# ## import the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv("telecom.csv")
df
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %% [markdown]
# ## Find the shape of the dataset

# %%
df.shape
# Out:
# (3333, 21)

# %% [markdown]
# ## Display the columns

# %%
df.columns
# Out:
# Index(['state', 'account length', 'area code', 'phone number',
#        'international plan', 'voice mail plan', 'number vmail messages',
#        'total day minutes', 'total day calls', 'total day charge',
#        'total eve minutes', 'total eve calls', 'total eve charge',
#        'total night minutes', 'total night calls', 'total night charge',
#        'total intl minutes', 'total intl calls', 'total intl charge',
#        'customer service calls', 'churn'],
#       dtype='object')

# %% [markdown]
# ## print the info of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   int64
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
# ...

# %% [markdown]
# ## print the datatype for each column

# %%
df.dtypes
# Out:
# state                      object
# account length              int64
# area code                   int64
# phone number               object
# international plan         object
# voice mail plan            object
# number vmail messages       int64
# total day minutes         float64
# total day calls             int64
# total day charge          float64
# total eve minutes         float64
# total eve calls             int64
# total eve charge          float64
# total night minutes       float64
# total night calls           int64
# total night charge        float64
# total intl minutes        float64
# total intl calls            int64
# total intl charge         float64
# customer service calls      int64
# churn                        bool
# dtype: object

# %% [markdown]
# ## change the column churn type from bool to int64 using astype method using numpy

# %%
df['churn'] = df['churn'].astype("int64")

# %% [markdown]
# ## display the dtype

# %%
df.dtypes
# Out:
# state                      object
# account length              int64
# area code                   int64
# phone number               object
# international plan         object
# voice mail plan            object
# number vmail messages       int64
# total day minutes         float64
# total day calls             int64
# total day charge          float64
# total eve minutes         float64
# total eve calls             int64
# total eve charge          float64
# total night minutes       float64
# total night calls           int64
# total night charge        float64
# total intl minutes        float64
# total intl calls            int64
# total intl charge         float64
# customer service calls      int64
# churn                       int64
# dtype: object

# %% [markdown]
# ## Describe the dataset

# %%
df.describe()
# Out:
#        account length    area code  number vmail messages  total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %% [markdown]
# ## use value_count method to display the count of churn column

# %%
df.columns
# Out:
# Index(['state', 'account length', 'area code', 'phone number',
#        'international plan', 'voice mail plan', 'number vmail messages',
#        'total day minutes', 'total day calls', 'total day charge',
#        'total eve minutes', 'total eve calls', 'total eve charge',
#        'total night minutes', 'total night calls', 'total night charge',
#        'total intl minutes', 'total intl calls', 'total intl charge',
#        'customer service calls', 'churn'],
#       dtype='object')

# %%
df['churn'].value_counts()
# Out:
# 0    2850
# 1     483
# Name: churn, dtype: int64

# %%
df["churn"].value_counts(normalize=True)
# Out:
# 0    0.855086
# 1    0.144914
# Name: churn, dtype: float64

# %% [markdown]
# ## sort  'Total day charge' column in descending order

# %%
df.sort_values(by="total day charge", ascending=False).head()
# Out:
#      state  account length  area code phone number international plan  \
# 365     CO             154        415     343-5709                 no
# 985     NY              64        415     345-9140                yes
# 2594    OH             115        510     348-1163                yes
# 156     OH              83        415     370-9116                 no
# 605     MO             112        415     373-2053                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 365               no                      0              350.8
# 985               no                      0              346.8
# 2594              no                      0              345.3
# 156               no                      0              337.4
# 605               no                      0              335.5
#
#       total day calls  total day charge  ...  total eve calls  \
# 365                75             59.64  ...               94
# ...

# %% [markdown]
# ## sort  'Total day charge' column in descending order. churn column in ascending order

# %%
df.sort_values(by=["churn", "total day charge"], ascending=[True, False]).head()
# Out:
#      state  account length  area code phone number international plan  \
# 688     MN              13        510     338-7120                 no
# 2259    NC             210        415     363-7802                 no
# 534     LA              67        510     373-6784                 no
# 575     SD             114        415     351-7369                 no
# 2858    AL             141        510     388-8583                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 688              yes                     21              315.6
# 2259             yes                     31              313.8
# 534               no                      0              310.4
# 575              yes                     36              309.9
# 2858             yes                     28              308.0
#
#       total day calls  total day charge  ...  total eve calls  \
# 688               105             53.65  ...               71
# ...

# %% [markdown]
# ## Find the mean for churn column

# %%
df['churn'].mean()
# Out:
# 0.14491449144914492

# %% [markdown]
# ## Find the mean for churn column ==1

# %%
df[df["churn"] == 0].mean()
# Out:
# state                     NaN
# account length            NaN
# area code                 NaN
# phone number              NaN
# international plan        NaN
# voice mail plan           NaN
# number vmail messages     NaN
# total day minutes         NaN
# total day calls           NaN
# total day charge          NaN
# total eve minutes         NaN
# total eve calls           NaN
# total eve charge          NaN
# total night minutes       NaN
# total night calls         NaN
# total night charge        NaN
# total intl minutes        NaN
# total intl calls          NaN
# total intl charge         NaN
# customer service calls    NaN
# churn                     NaN
# dtype: object
